# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielaForcinito/computational-1/blob/main/Computational_reproducibility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# date
print("10/30/24")
# simple arithmetic operation
2*5
# Out:
# 10/30/24
# 10

# %% [markdown]
# ![image.png](data:image/png;base64,...)
